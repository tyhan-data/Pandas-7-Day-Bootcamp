# %%
# import libraries....
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Load dataset
df = pd.read_csv(r'C:\Dataset for practice/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Missing Value finding section

# %%
# First explore the total rows and columns
df.shape
# Out:
# (891, 12)

# %%
# Missing data
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Show the percentage of missing
(df.isnull().sum()/df.shape[0])*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
# Total data
df.notnull().sum().sum()
# Out:
# np.int64(9826)

# %%
# Show the total data missing
df.isnull().sum().sum()
# Out:
# np.int64(866)

# %%
# percentage of missing data in the dataset
(df.isnull().sum().sum()/(df.shape[0]*df.shape[1]))*100
# Out:
# np.float64(8.099513655069211)

# %%
# Missing data Visualization
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# # Cleaning section

# %%
# Delete the cabin column
df.drop(columns=['Cabin'], inplace =True)

# %%
df.shape
# Out:
# (891, 11)

# %%
# If you want to delete row wise data
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (712, 11)

# %%
# Percentage of data we lost 
((891-712)/(891))*100
# Out:
# 20.089786756453424

# %% [markdown]
# # Data Filling section

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [raw]
# - If we want to fill categoricals data , so we can use forward fill, beckward fill and mode.

# %%
# First forward fill
df.fillna(method='ffill')  # we will not use 'inplace=True', because we don't want to change original dataset.
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Second backward fill
df.fillna(method='bfill')  # we will not use 'inplace=True', because we don't want to change original dataset.
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [raw]
# In ffill and bfill, We are see a problem, And that is when we use ffill our first row has still null value and
# when we use bfill our last row has also still null value. So in here we can use mode, to avoid this kind of problem'

# %%
# Last on is mode. We will just fill Cabin column
df['Cabin'].fillna(df['Cabin'].mode()[0]).to_frame()    # we will not use 'inplace=True', because we don't want to change original dataset.
# Out:
#        Cabin
# 0    B96 B98
# 1        C85
# 2    B96 B98
# 3       C123
# 4    B96 B98
# ..       ...
# 886  B96 B98
# 887      B42
# 888  B96 B98
# 889     C148
# 890  B96 B98
#
# [891 rows x 1 columns]

# %%
# This is the way to fill all categoricals dtype columns.
for i in df.select_dtypes(include='object').columns:
    df[i].fillna(df[i].mode()[0], inplace = True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin            0
# Embarked         0
# dtype: int64

# %%
# Now it's time to fill the numerical dtype column age
df['Age'].fillna(df['Age'].mean(), inplace = True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64
