# %% [markdown]
# # 🥈 DAY 2 — loc, iloc, Filtering (Core Skill)
# # Customer Dataset

# %%
import pandas as pd

df = pd.read_csv("../New folder/Project_Assignment/Cust_Purch_FakeData.csv")
df1 = pd.read_csv('../numpy_practice/jupyter/pandas_practice/Movies_dataset.csv')
df2 = pd.read_csv('../numpy_practice/jupyter/pandas_practice/top_250_imdb_dataset.csv')
df3 = pd.read_csv('../numpy_practice/jupyter/pandas_practice/Students Social Media Addiction.csv')

# %%
# 1️⃣ Age > 30

df[df['age'] > 30]
# Out:
#       prefix    first       last              email  gender  age  \
# 0        Dr.      Ray     Morton    sebvajom@kol.km    Male   38
# 1       Miss  Claudia  Rodriquez      acu@jatsot.ug  Female   51
# 2       Miss    Harry      Meyer          zuz@lo.wf  Female   51
# 3       Miss    Edith    Gilbert  hansohsi@jupec.md  Female   55
# 5       Mrs.    Andre    McGuire        to@hotvo.ne    Male   50
# ...      ...      ...        ...                ...     ...  ...
# 29993    Mr.   Herman    Ballard           di@vu.mz  Female   52
# 29994   Miss   Dennis     Adkins    oloepmul@osu.pm  Female   57
# 29995    Mr.     John    Maxwell  larlisu@sejenu.ad  Female   38
# 29997   Mrs.   Edward     Curtis      ta@kucemah.et  Female   56
# 29998    Mr.      Max      Woods       li@mincoz.mp  Female   64
#
#                              company                profession  \
# 0                     Medtronic Inc.          Health Therapist
# ...

# %%
# 2️⃣ Purchase amount >= 100

df[df['price(CAD)'] >= 100]
# Out:
#       prefix    first         last          email  gender  age  \
# 76      Mrs.  Gregory        Brown     hav@jek.gs  Female   31
# 21093   Mrs.     Cody  Christensen    get@jovu.ag    Male   28
# 24385   Miss   Lizzie        Dixon  goh@tuwjaz.gd  Female   38
#
#                          company              profession           phone  \
# 76           E*Trade Group, Inc.                Novelist  (625) 537-8923
# 21093        National City Corp.  Hospital Administrator  (261) 737-3292
# 24385  FleetBoston Financial Co.    Compensation Analyst  (989) 239-1752
#
#         postal province             cc_no   cc_exp   cc_type  price(CAD)  \
# 76     X3S 4Q2       PE  6010000000000000  04/2018      Visa       100.0
# 21093  X0S 1O5       PE   201000000000000  03/2024       JCB       100.0
# 24385  V8X 9V6       NB  6300000000000000  07/2019  Bankcard       100.0
#
#       fav_color             ip    weekday ampm        date
# 76        Green  212.100.18.95     Monday   am  10/23/2063
# ...

# %%
# 3️⃣ Age between 25 and 40

df[df['age'].between(25, 40)]
# Out:
#       prefix     first       last                email  gender  age  \
# 0        Dr.       Ray     Morton      sebvajom@kol.km    Male   38
# 7        Mr.      Cory     Duncan      rucekefif@zi.mt    Male   36
# 8       Miss   Dorothy    Watkins        cakpez@can.pm  Female   36
# 11       Dr.    Rodney   Anderson  iddegape@mocosak.gr  Female   27
# 13       Mr.   Lucinda  Zimmerman         owo@fiise.gt  Female   36
# ...      ...       ...        ...                  ...     ...  ...
# 29987    Mr.     Billy      Lucas       hihdu@kuwze.hm  Female   38
# 29989    Dr.    Stella     Pierce     durif@kaazile.td    Male   27
# 29990   Mrs.  Theodore      Lewis         nof@vowna.cz  Female   33
# 29992    Mr.   Leonard     Flores           fi@luak.au  Female   36
# 29995    Mr.      John    Maxwell    larlisu@sejenu.ad  Female   38
#
#                                    company  \
# 0                           Medtronic Inc.
# 7      Integrated Electrical Services Inc.
# ...

# %%
# 4️⃣ Total Female customers

total = df[df['gender'] == 'Female'].shape[0]
print('Total female customers:', total)
# Out:
# Total female customers: 15147

# %%
# 5️⃣ Customers from USA

df2[df2['Country'] == 'USA'].head()
# Out:
#      Student_ID  Age  Gender Academic_Level Country  Avg_Daily_Usage_Hours  \
# 2             3   20  Female  Undergraduate     USA                    6.0
# 220         221   19  Female  Undergraduate     USA                    6.5
# 228         229   19  Female  Undergraduate     USA                    7.0
# 236         237   19  Female  Undergraduate     USA                    6.8
# 244         245   19  Female  Undergraduate     USA                    6.9
#
#     Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 2               TikTok                          Yes                    5.0
# 220          Instagram                          Yes                    6.0
# 228             TikTok                          Yes                    5.8
# 236          Instagram                          Yes                    5.9
# 244             TikTok                          Yes                    5.7
#
# ...

# %%
# 6️⃣ Email contains "gmail"

df[df['email'].str.contains('gmail')].reset_index()
# Out:
#       index prefix    first      last                email  gender  age  \
# 0       198    Mr.    Jerry      Moss  jufkettug@gmail.com    Male   43
# 1       201    Mr.    Peter    Gibson   oniweput@gmail.com    Male   27
# 2       204   Miss    Gavin  Gonzales   gebasise@gmail.com    Male   62
# 3       205    Dr.    Peter     Reese      sefed@gmail.com    Male   55
# 4       209    Dr.     Rose      Dean     robleg@gmail.com    Male   35
# ...     ...    ...      ...       ...                  ...     ...  ...
# 1682   5176   Mrs.  Chester    Norton    dehozic@gmail.com    Male   37
# 1683   5183   Mrs.     Cole    Medina    vuputum@gmail.com  Female   23
# 1684   5184    Mr.   Lettie   Pittman   pofizwew@gmail.com    Male   55
# 1685   5192   Miss     Lola      Webb   ledhinep@gmail.com    Male   32
# 1686   5196    Mr.   Jeremy    Oliver      uhepu@gmail.com  Female   44
#
#                                                 company  \
# ...

# %% [markdown]
# # Movies Dataset

# %%
# 7️⃣ Movies after 2018

# first convert object data type into datetime data type.
df1['release_date'] = pd.to_datetime( df1['release_date'])
df1['year'] = df1['release_date'].dt.year

df1[df1['year'] > 2018].head()
# Out:
#         id                         original_title original_language  \
# 9   496243                                    기생충                ko
# 25  667257                       Cosas imposibles                es
# 30  696374                      Gabriel's Inferno                en
# 40  770156  Lucy Shimmers and the Prince of Peace                en
# 42  724089             Gabriel's Inferno: Part II                en
#
#                       genre  \
# 9   Comedy, Thriller, Drama
# 25            Family, Drama
# 30           Romance, Drama
# 40            Drama, Family
# 42           Romance, Drama
#
#                                              overview  popularity  vote_count  \
# 9   All unemployed, Ki-taek's family takes peculia...     18.8551       19826
# 25  After the death of her abusive husband, Matild...      4.3798         418
# 30  An intriguing and sinful exploration of seduct...      3.6654        2438
# ...

# %%
# 8️⃣ Movies duration > 150

df2[df2['Duration_Minutes'] > 150].head()
# Out:
#    Rank                                          Title  Year  Rating  \
# 1     2                                  The Godfather  1972     NaN
# 2     3                                The Dark Knight  2008     NaN
# 3     4                          The Godfather Part II  1974     NaN
# 5     6  The Lord of the Rings: The Return of the King  2003     NaN
# 6     7                               Schindler's List  1993     NaN
#
#    Duration_Minutes Certificate        Source
# 1               175           R  IMDb Top 250
# 2               152       PG-13  IMDb Top 250
# 3               202           R  IMDb Top 250
# 5               201       PG-13  IMDb Top 250
# 6               195           R  IMDb Top 250

# %%
# 9️⃣ Movies between 2010 and 2020

df1[df1['year'].between(2010, 2020)].head()
# Out:
#         id     original_title original_language  \
# 9   496243                기생충                ko
# 12  372058              君の名は。                ja
# 14  157336       Interstellar                en
# 30  696374  Gabriel's Inferno                en
# 31  255709                 소원                ko
#
#                                 genre  \
# 9             Comedy, Thriller, Drama
# 12          Animation, Romance, Drama
# 14  Adventure, Drama, Science Fiction
# 30                     Romance, Drama
# 31                              Drama
#
#                                              overview  popularity  vote_count  \
# 9   All unemployed, Ki-taek's family takes peculia...     18.8551       19826
# 12  High schoolers Mitsuha and Taki are complete s...     18.0858       12165
# 14  The adventures of a group of explorers who mak...     45.8189       38436
# 30  An intriguing and sinful exploration of seduct...      3.6654        2438
# ...

# %%
# 🔟 Movies with votes > 10000

df1[df1['vote_count'] > 10000].head()
# Out:
#     id            original_title original_language  \
# 0  278  The Shawshank Redemption                en
# 1  238             The Godfather                en
# 2  240     The Godfather Part II                en
# 3  424          Schindler's List                en
# 5  129                  千と千尋の神隠し                ja
#
#                         genre  \
# 0                Drama, Crime
# 1                Drama, Crime
# 2                Drama, Crime
# 3         Drama, History, War
# 5  Animation, Family, Fantasy
#
#                                             overview  popularity  vote_count  \
# 0  Imprisoned in the 1940s for the double murder ...     36.1467       29384
# 1  Spanning the years 1945 to 1955, a chronicle o...     37.3341       22174
# 2  In the continuing saga of the Corleone crime f...     14.6729       13404
# 3  The true story of how businessman Oskar Schind...     13.6783       16923
# 5  A young girl, Chihiro, becomes trapped in a st...     25.6839       17726
#
# ...

# %% [markdown]
# # Students Dataset

# %%
# 1️⃣1️⃣ Sleep < 6

df3[df3['Sleep_Hours_Per_Night'] < 6]
# Out:
#      Student_ID  Age  Gender Academic_Level    Country  Avg_Daily_Usage_Hours  \
# 2             3   20  Female  Undergraduate        USA                    6.0
# 5             6   19  Female  Undergraduate  Australia                    7.2
# 11           12   20  Female  Undergraduate      Spain                    5.5
# 13           14   18  Female    High School     Mexico                    6.5
# 17           18   19  Female    High School     Norway                    5.0
# ..          ...  ...     ...            ...        ...                    ...
# 658         659   20  Female  Undergraduate      India                    7.1
# 667         668   24    Male       Graduate     Russia                    6.9
# 675         676   22    Male       Graduate      India                    7.2
# 692         693   19  Female  Undergraduate      India                    7.0
# 701         702   23    Male       Graduate     Russia                    6.8
#
# ...

# %%
# 1️⃣2️⃣ Addiction score ≥ 8

df3[df3['Addicted_Score'] >= 8]
# Out:
#      Student_ID  Age  Gender Academic_Level     Country  \
# 0             1   19  Female  Undergraduate  Bangladesh
# 2             3   20  Female  Undergraduate         USA
# 5             6   19  Female  Undergraduate   Australia
# 7             8   20  Female  Undergraduate      Brazil
# 11           12   20  Female  Undergraduate       Spain
# ..          ...  ...     ...            ...         ...
# 694         695   20  Female  Undergraduate      Turkey
# 696         697   21  Female  Undergraduate      Mexico
# 699         700   22    Male       Graduate          UK
# 701         702   23    Male       Graduate      Russia
# 704         705   19  Female  Undergraduate      Poland
#
#      Avg_Daily_Usage_Hours Most_Used_Platform Affects_Academic_Performance  \
# 0                      5.2          Instagram                          Yes
# 2                      6.0             TikTok                          Yes
# ...

# %%
# 1️⃣3️⃣ Daily usage > 5

df3[df3['Avg_Daily_Usage_Hours'] > 5]
# Out:
#      Student_ID  Age  Gender Academic_Level     Country  \
# 0             1   19  Female  Undergraduate  Bangladesh
# 2             3   20  Female  Undergraduate         USA
# 5             6   19  Female  Undergraduate   Australia
# 7             8   20  Female  Undergraduate      Brazil
# 11           12   20  Female  Undergraduate       Spain
# ..          ...  ...     ...            ...         ...
# 698         699   19  Female  Undergraduate      Canada
# 699         700   22    Male       Graduate          UK
# 701         702   23    Male       Graduate      Russia
# 702         703   21  Female  Undergraduate       China
# 704         705   19  Female  Undergraduate      Poland
#
#      Avg_Daily_Usage_Hours Most_Used_Platform Affects_Academic_Performance  \
# 0                      5.2          Instagram                          Yes
# 2                      6.0             TikTok                          Yes
# ...

# %%
# 1️⃣4️⃣ Students from Bangladesh

df3[df3['Country'] == 'Bangladesh']
# Out:
#      Student_ID  Age  Gender Academic_Level     Country  \
# 0             1   19  Female  Undergraduate  Bangladesh
# 110         111   20    Male  Undergraduate  Bangladesh
# 116         117   21    Male       Graduate  Bangladesh
# 122         123   19    Male  Undergraduate  Bangladesh
# 128         129   22    Male       Graduate  Bangladesh
# 134         135   19    Male  Undergraduate  Bangladesh
# 140         141   22    Male       Graduate  Bangladesh
# 146         147   19    Male  Undergraduate  Bangladesh
# 152         153   22    Male       Graduate  Bangladesh
# 158         159   19    Male  Undergraduate  Bangladesh
# 160         161   19  Female  Undergraduate  Bangladesh
# 166         167   20  Female  Undergraduate  Bangladesh
# 172         173   19  Female  Undergraduate  Bangladesh
# 178         179   20  Female  Undergraduate  Bangladesh
# 184         185   19  Female  Undergraduate  Bangladesh
# 190         191   20  Female  Undergraduate  Bangladesh
# ...

# %%
# 1️⃣5️⃣ Combined: addiction ≥ 8 AND sleep < 6

df3[(df3['Addicted_Score'] >= 8) & (df3['Sleep_Hours_Per_Night'] < 6)]
# Out:
#      Student_ID  Age  Gender Academic_Level    Country  Avg_Daily_Usage_Hours  \
# 2             3   20  Female  Undergraduate        USA                    6.0
# 5             6   19  Female  Undergraduate  Australia                    7.2
# 11           12   20  Female  Undergraduate      Spain                    5.5
# 13           14   18  Female    High School     Mexico                    6.5
# 17           18   19  Female    High School     Norway                    5.0
# ..          ...  ...     ...            ...        ...                    ...
# 658         659   20  Female  Undergraduate      India                    7.1
# 667         668   24    Male       Graduate     Russia                    6.9
# 675         676   22    Male       Graduate      India                    7.2
# 692         693   19  Female  Undergraduate      India                    7.0
# 701         702   23    Male       Graduate     Russia                    6.8
#
# ...
